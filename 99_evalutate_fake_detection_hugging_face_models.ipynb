# %%
import numpy as np
import pandas as pd

import os

import time
import logging

from transformers import pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
file_path = '/Users/alex_fassone/Documents/MSc Statistics/ST456/Coursework/Project/Data'
file_path_combined = file_path + '/Combined'

def load_combined_split(filename):
    path = os.path.join(file_path_combined, filename)
    df = pd.read_csv(path)
    return df

# %%
test_df = load_combined_split('test_df.csv')

# %%
input_df = test_df

# %%
def add_model_predictions(input_df, model_name, text_column='text', batch_size=32):
    """
    Adds predicted label and probability columns to input_df using a Hugging Face model.
    
    Parameters:
        input_df (pd.DataFrame): The input dataframe containing text.
        model_name (str): The Hugging Face model identifier.
        text_column (str): Column in the dataframe with input text.
        
    Returns:
        pd.DataFrame: A copy of the dataframe with new prediction columns.
    """

    logger.info(f"Loading model: {model_name}")

    # Create prediction pipeline
    pipe = pipeline(
        "text-classification", 
        model=model_name,
        tokenizer=model_name,
        truncation=True,
        padding=True,
        max_length=512
    )

    logger.info("Model and tokenizer loaded.")

    # Process in batches
    texts = input_df[text_column].tolist()
    total = len(texts)
    predictions = []

    logger.info(f"Starting prediction on {total} samples (batch size = {batch_size})...")   

    # Get predictions
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        preds = pipe(batch)
        predictions.extend(preds)
        logger.info(f"Processed {min(i + batch_size, total)} / {total}")

    # Parse outputs
    predicted_labels = [0 if pred['label'] == 'LABEL_0' else 1 for pred in predictions]
    predicted_probs = [pred['score'] for pred in predictions]

    # Format column names
    label_col = f'predicted_label_{model_name.split("/")[-1]}'
    #prob_col = f'predicted_prob_{model_name.split("/")[-1]}'

    logger.info(f"Added columns: {label_col}")

    # Return updated copy
    output_df = input_df.copy()
    output_df[label_col] = predicted_labels
    #output_df[prob_col] = predicted_probs

    return output_df

# %%
# Define your models
model_dict = {
    "Fake-News-Bert": "jy46604790/Fake-News-Bert-Detect",
    "DistilBERT-FakeNews": "harshhmaniya/fake-news-classification-distilbert-fine-tuned",
    "Albert-Base-v2": "XSY/albert-base-v2-fakenews-discriminator"
    # Add more models here...
}

# Start with the base DataFrame
df_with_preds = input_df.copy()

# Loop through and apply each model
for name, model_path in model_dict.items():
    print(f"\nRunning predictions for: {name}")
    df_with_preds = add_model_predictions(
        df_with_preds,
        model_name=model_path,
        text_column='text_clean',
        batch_size=100  # You can adjust this
    )
# Out:
# INFO:__main__:Loading model: jy46604790/Fake-News-Bert-Detect
# Running predictions for: Fake-News-Bert
# Device set to use mps:0
# INFO:__main__:Model and tokenizer loaded.
# INFO:__main__:Starting prediction on 20000 samples (batch size = 100)...
# INFO:__main__:Processed 100 / 20000
# INFO:__main__:Processed 200 / 20000
# INFO:__main__:Processed 300 / 20000
# INFO:__main__:Processed 400 / 20000
# INFO:__main__:Processed 500 / 20000
# INFO:__main__:Processed 600 / 20000
# INFO:__main__:Processed 700 / 20000
# INFO:__main__:Processed 800 / 20000
# INFO:__main__:Processed 900 / 20000
# INFO:__main__:Processed 1000 / 20000
# INFO:__main__:Processed 1100 / 20000
# INFO:__main__:Processed 15500 / 20000
# INFO:__main__:Processed 15600 / 20000
# INFO:__main__:Processed 15700 / 20000
# INFO:__main__:Processed 15800 / 20000
# INFO:__main__:Processed 15900 / 20000
# INFO:__main__:Processed 16000 / 20000
# INFO:__main__:Processed 16100 / 20000
# INFO:__main__:Processed 16200 / 20000
# INFO:__main__:Processed 16300 / 20000
# INFO:__main__:Processed 16400 / 20000
# INFO:__main__:Processed 16500 / 20000
# INFO:__main__:Processed 16600 / 20000
# INFO:__main__:Processed 16700 / 20000
# INFO:__main__:Processed 16800 / 20000
# INFO:__main__:Processed 16900 / 20000
# INFO:__main__:Processed 17000 / 20000
# INFO:__main__:Processed 17100 / 20000
# INFO:__main__:Processed 17200 / 20000
# INFO:__main__:Processed 17300 / 20000
# INFO:__main__:Processed 17400 / 20000
# INFO:__main__:Processed 17500 / 20000
# INFO:__main__:Processed 17600 / 20000
# INFO:__main__:Processed 17700 / 20000
# INFO:__main__:Processed 17800 / 20000
# INFO:__main__:Processed 17900 / 20000
# INFO:__main__:Processed 18000 / 20000
# INFO:__main__:Processed 18100 / 20000
# INFO:__main__:Processed 18200 / 20000
# INFO:__main__:Processed 18300 / 20000
# INFO:__main__:Processed 18400 / 20000
# INFO:__main__:Processed 18500 / 20000
# INFO:__main__:Processed 18600 / 20000
# INFO:__main__:Processed 18700 / 20000
# INFO:__main__:Processed 18800 / 20000
# INFO:__main__:Processed 18900 / 20000
# INFO:__main__:Processed 19000 / 20000
# INFO:__main__:Processed 19100 / 20000
# INFO:__main__:Processed 19200 / 20000
# INFO:__main__:Processed 19300 / 20000
# INFO:__main__:Processed 19400 / 20000
# INFO:__main__:Processed 19500 / 20000
# INFO:__main__:Processed 19600 / 20000
# INFO:__main__:Processed 19700 / 20000
# INFO:__main__:Processed 19800 / 20000
# INFO:__main__:Processed 19900 / 20000
# INFO:__main__:Processed 20000 / 20000
# INFO:__main__:Added columns: predicted_label_albert-base-v2-fakenews-discriminator

# %%
def evaluate_model_predictions(df, label_col='binary_label', group_by_dataset=False):
    """
    Evaluate prediction performance for each model in the DataFrame.

    Parameters:
        df (pd.DataFrame): DataFrame containing ground truth and predicted labels.
        label_col (str): Column name of the ground truth labels.
        group_by_dataset (bool): If True, compute metrics grouped by 'dataset'.

    Returns:
        pd.DataFrame: DataFrame of evaluation metrics.
    """
    metrics = []
    pred_cols = [col for col in df.columns if col.startswith('predicted_label_')]

    if group_by_dataset:
        grouped = df.groupby('dataset')
        for dataset_name, group in grouped:
            for col in pred_cols:
                y_true = group[label_col]
                y_pred = group[col]
                model_name = col.replace('predicted_label_', '')
                
                metrics.append({
                    'dataset': dataset_name,
                    'model': model_name,
                    'accuracy': accuracy_score(y_true, y_pred),
                    'precision': precision_score(y_true, y_pred, zero_division=0),
                    'recall': recall_score(y_true, y_pred, zero_division=0),
                    'f1_score': f1_score(y_true, y_pred, zero_division=0)
                })
    else:
        for col in pred_cols:
            y_true = df[label_col]
            y_pred = df[col]
            model_name = col.replace('predicted_label_', '')
            
            metrics.append({
                'dataset': 'ALL',
                'model': model_name,
                'accuracy': accuracy_score(y_true, y_pred),
                'precision': precision_score(y_true, y_pred, zero_division=0),
                'recall': recall_score(y_true, y_pred, zero_division=0),
                'f1_score': f1_score(y_true, y_pred, zero_division=0)
            })

    return pd.DataFrame(metrics)

# %%
overall_model_metrics = evaluate_model_predictions(df_with_preds)
dataset_grouped_model_metrics = evaluate_model_predictions(df_with_preds, group_by_dataset=True)

# %%
overall_model_metrics
# Out:
#   dataset                                           model  accuracy  \
# 0     ALL                           Fake-News-Bert-Detect   0.50290
# 1     ALL  fake-news-classification-distilbert-fine-tuned   0.47860
# 2     ALL           albert-base-v2-fakenews-discriminator   0.48685
#
#    precision    recall  f1_score
# 0   0.941535  0.072466  0.134575
# 1   0.979920  0.022874  0.044705
# 2   0.566579  0.161151  0.250931

# %%
dataset_grouped_model_metrics
# Out:
#                            dataset  \
# 0                         Fakeddit
# 1                         Fakeddit
# 2                         Fakeddit
# 3             Kaggle 1 - Fake News
# 4             Kaggle 1 - Fake News
# 5             Kaggle 1 - Fake News
# 6          Kaggle 2 - News Project
# 7          Kaggle 2 - News Project
# 8          Kaggle 2 - News Project
# 9   Kaggle 3 - Fake News Detection
# 10  Kaggle 3 - Fake News Detection
# 11  Kaggle 3 - Fake News Detection
# 12                          LIAR 2
# 13                          LIAR 2
# 14                          LIAR 2
#
#                                              model  accuracy  precision  \
# 0                            Fake-News-Bert-Detect   0.45975   0.761905
# 1   fake-news-classification-distilbert-fine-tuned   0.45725   1.000000
# 2            albert-base-v2-fakenews-discriminator   0.48750   0.543140
# 3                            Fake-News-Bert-Detect   0.58250   0.995316
# 4   fake-news-classification-distilbert-fine-tuned   0.52650   0.995025
# 5            albert-base-v2-fakenews-discriminator   0.54175   0.869318
# 6                            Fake-News-Bert-Detect   0.44500   0.563636
# 7   fake-news-classification-distilbert-fine-tuned   0.44325   0.500000
# 8            albert-base-v2-fakenews-discriminator   0.45525   0.657895
# 9                            Fake-News-Bert-Detect   0.44625   0.963455
# 10  fake-news-classification-distilbert-fine-tuned   0.38600   0.952381
# 11           albert-base-v2-fakenews-discriminator   0.40600   0.700680
# 12                           Fake-News-Bert-Detect   0.58100   0.647059
# 13  fake-news-classification-distilbert-fine-tuned   0.58000   1.000000
# 14           albert-base-v2-fakenews-discriminator   0.54375   0.412409
#
#       recall  f1_score
# 0   0.007366  0.014592
# 1   0.000460  0.000920
# 2   0.353591  0.428332
# 3   0.203058  0.337302
# 4   0.095557  0.174368
# 5   0.146202  0.250307
# 6   0.013920  0.027169
# 7   0.000898  0.001793
# 8   0.044903  0.084069
# 9   0.116279  0.207513
# 10  0.016038  0.031546
# 11  0.082598  0.147776
# 12  0.006544  0.012956
# 13  0.000595  0.001189
# 14  0.201666  0.270875
